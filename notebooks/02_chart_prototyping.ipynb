# %% [markdown]
# # Chart prototyping: qualitative validation
#
# Load the real cleaned MoMA data and inspect the Mondrian chart against the source image. Does it honestly represent the data, and does it still read as the source composition?

# %%
import sys
sys.path.insert(0, "..")

from src import data, charts

df = data.load_raw_data()
cleaned = data.clean_artworks(df)
cleaned.shape

# %% [markdown]
# ## Mondrian treemap
#
# Inspect: does the treemap read as a grid of red/blue/yellow/black blocks? Are the categories legible (not one giant dominant tile swallowing the rest)?

# %%
charts.mondrian_treemap(cleaned).show()

# %% [markdown]
# ## Findings
#
# _Fill in after inspecting the chart above: pass as-is, or note the specific follow-up needed. Do not silently fix issues here — log them as README Progress/Next-steps bullets and open a follow-up task instead._
